# %% [markdown]
# # Creating your own dataset from Google Images
#
# *by: Francisco Ingham and Jeremy Howard. Inspired by [Adrian Rosebrock](https://www.pyimagesearch.com/2017/12/04/how-to-create-a-deep-learning-dataset-using-google-images/)*

# %% [markdown]
# In this tutorial we will see how to easily create an image dataset through Google Images. **Note**: You will have to repeat these steps for any new category you want to Google (e.g once for dogs and once for cats).

# %% [markdown]
# ## Get a list of URLs

# %% [markdown]
# ### Search and scroll

# %% [markdown]
# Go to [Google Images](http://images.google.com) and search for the images you are interested in. The more specific you are in your Google Search, the better the results and the less manual pruning you will have to do.
#
# Scroll down until you've seen all the images you want to download, or until you see a button that says 'Show more results'. All the images you scrolled past are now available to download. To get more, click on the button, and continue scrolling. The maximum number of images Google Images shows is 700.
#
# It is a good idea to put things you want to exclude into the search query, for instance if you are searching for the Eurasian wolf, "canis lupus lupus", it might be a good idea to exclude other variants:
#
#     "canis lupus lupus" -dog -arctos -familiaris -baileyi -occidentalis
#
# You can also limit your results to show only photos by clicking on Tools and selecting Photos from the Type dropdown.

# %% [markdown]
# ### Download into file

# %% [markdown]
# Now you must run some Javascript code in your browser which will save the URLs of all the images you want for you dataset.
#
# Press <kbd>Ctrl</kbd><kbd>Shift</kbd><kbd>J</kbd> in Windows/Linux and <kbd>Cmd</kbd><kbd>Opt</kbd><kbd>J</kbd> in Mac, and a small window the javascript 'Console' will appear. That is where you will paste the JavaScript commands.
#
# You will need to get the urls of each of the images. You can do this by running the following commands:
#
# ```javascript
# urls = Array.from(document.querySelectorAll('.rg_di .rg_meta')).map(el=>JSON.parse(el.textContent).ou);
# window.open('data:text/csv;charset=utf-8,' + escape(urls.join('\n')));
# ```

# %% [markdown]
# ### Create directory and upload urls file into your server

# %%
from fastai import *
from fastai.vision import *

# %%
# !pip list
# Out:
# Package                            Version
# ---------------------------------- -----------------
# absl-py                            0.5.0
# alabaster                          0.7.11
# anaconda-client                    1.7.2
# anaconda-navigator                 1.9.2
# anaconda-project                   0.8.2
# appdirs                            1.4.3
# appnope                            0.1.0
# appscript                          1.0.1
# args                               0.1.0
# asn1crypto                         0.24.0
# astor                              0.7.1
# astroid                            2.0.4
# astropy                            3.0.4
# atomicwrites                       1.2.1
# attrs                              18.2.0
# Automat                            0.7.0
# Babel                              2.6.0
# backcall                           0.1.0
# backports.shutil-get-terminal-size 1.0.0
# beautifulsoup4                     4.6.3
# bitarray                           0.8.3
# bkcharts                           0.2
# blaze                              0.11.3
# bleach                             2.1.4
# bokeh                              0.13.0
# boto                               2.49.0
# Bottleneck                         1.2.1
# category-encoders                  1.3.0
# certifi                            2018.10.15
# cffi                               1.11.5
# chardet                            3.0.4
# click                              6.7
# clint                              0.5.1
# cloudpickle                        0.5.6
# clyent                             1.2.2
# colorama                           0.3.9
# colorlover                         0.2.1
# conda                              4.5.11
# conda-build                        3.15.1
# constantly                         15.1.0
# contextlib2                        0.5.5
# cryptography                       2.3.1
# cssselect                          1.0.3
# cycler                             0.10.0
# cymem                              2.0.2
# Cython                             0.28.5
# cytoolz                            0.9.0.1
# dask                               0.19.2
# dataclasses                        0.6
# datashape                          0.5.4
# deap                               1.2.2
# decorator                          4.3.0
# defusedxml                         0.5.0
# dill                               0.2.8.2
# distributed                        1.23.2
# docutils                           0.14
# entrypoints                        0.2.3
# et-xmlfile                         1.0.1
# fastai                             1.0.18
# fastcache                          1.0.2
# fastprogress                       0.1.15
# filelock                           3.0.8
# Flask                              1.0.2
# Flask-Cors                         3.0.6
# gast                               0.2.0
# gevent                             1.3.6
# glob2                              0.6
# gmpy2                              2.0.8
# greenlet                           0.4.15
# grpcio                             1.12.1
# h5py                               2.8.0
# heapdict                           1.0.0
# html5lib                           1.0.1
# hyperlink                          18.0.0
# idna                               2.7
# imageio                            2.4.1
# imagesize                          1.1.0
# incremental                        17.5.0
# ipykernel                          4.10.0
# ipython                            6.5.0
# ipython-genutils                   0.2.0
# ipywidgets                         7.4.2
# isort                              4.3.4
# itsdangerous                       0.24
# jdcal                              1.4
# jedi                               0.12.1
# Jinja2                             2.10
# jsonschema                         2.6.0
# jupyter                            1.0.0
# jupyter-client                     5.2.3
# jupyter-console                    5.2.0
# jupyter-core                       4.4.0
# jupyterlab                         0.34.12
# jupyterlab-launcher                0.13.1
# kaggle                             1.5.0
# Keras                              2.2.2
# Keras-Applications                 1.0.4
# Keras-Preprocessing                1.0.2
# keyring                            13.2.1
# kiwisolver                         1.0.1
# lazy-object-proxy                  1.3.1
# lightgbm                           2.1.2
# littleutils                        0.2.1
# llvmlite                           0.24.0
# locket                             0.2.0
# lxml                               4.2.5
# Markdown                           2.6.11
# MarkupSafe                         1.0
# marshmallow                        2.16.1
# matplotlib                         3.0.0
# mccabe                             0.6.1
# mistune                            0.8.3
# mkl-fft                            1.0.6
# mkl-random                         1.0.1
# more-itertools                     4.3.0
# mpmath                             1.0.0
# msgpack                            0.5.6
# msgpack-numpy                      0.4.3.2
# multipledispatch                   0.6.0
# murmurhash                         0.28.0
# navigator-updater                  0.2.1
# nbconvert                          5.4.0
# nbformat                           4.4.0
# networkx                           2.1
# nltk                               3.3
# nose                               1.3.7
# notebook                           5.7.0
# numba                              0.39.0
# numexpr                            2.6.8
# numpy                              1.15.2
# numpydoc                           0.8.0
# odo                                0.5.1
# olefile                            0.46
# openpyxl                           2.5.8
# outdated                           0.1.2
# packaging                          17.1
# pandas                             0.23.4
# pandas-datareader                  0.6.0
# pandocfilters                      1.4.2
# parsel                             1.5.0
# parso                              0.3.1
# partd                              0.3.8
# path.py                            11.1.0
# pathlib2                           2.3.2
# patsy                              0.5.0
# pep8                               1.7.1
# pexpect                            4.6.0
# pickleshare                        0.7.4
# Pillow                             5.3.0
# pip                                18.1
# pkginfo                            1.4.2
# plac                               0.9.6
# plotly                             3.3.0
# pluggy                             0.7.1
# ply                                3.11
# preshed                            2.0.1
# prometheus-client                  0.3.1
# prompt-toolkit                     1.0.15
# protobuf                           3.6.0
# psutil                             5.4.7
# ptyprocess                         0.6.0
# py                                 1.6.0
# pyasn1                             0.4.4
# pyasn1-modules                     0.2.2
# pycodestyle                        2.4.0
# pycosat                            0.6.3
# pycparser                          2.19
# pycrypto                           2.6.1
# pycurl                             7.43.0.2
# PyDispatcher                       2.0.5
# pyflakes                           2.0.0
# Pygments                           2.2.0
# pylint                             2.1.1
# pyodbc                             4.0.24
# pyOpenSSL                          18.0.0
# pyparsing                          2.2.1
# PySocks                            1.6.8
# pytest                             3.8.1
# pytest-arraydiff                   0.2
# pytest-astropy                     0.4.0
# pytest-doctestplus                 0.1.3
# pytest-openfiles                   0.3.0
# pytest-remotedata                  0.3.0
# pytest-runner                      4.2
# python-dateutil                    2.7.3
# python-slugify                     1.2.6
# pytz                               2018.5
# PyWavelets                         1.0.0
# PyYAML                             3.13
# pyzmq                              17.1.2
# QtAwesome                          0.5.0
# qtconsole                          4.4.1
# QtPy                               1.5.1
# queuelib                           1.5.0
# regex                              2018.8.29
# requests                           2.19.1
# requests-file                      1.4.3
# requests-ftp                       0.3.1
# requests-toolbelt                  0.8.0
# retrying                           1.3.3
# rope                               0.11.0
# ruamel-yaml                        0.15.46
# scikit-image                       0.14.0
# scikit-learn                       0.20.0
# scipy                              1.1.0
# Scrapy                             1.5.1
# seaborn                            0.9.0
# Send2Trash                         1.5.0
# service-identity                   17.0.0
# setuptools                         40.2.0
# simplegeneric                      0.8.1
# singledispatch                     3.4.0.3
# six                                1.11.0
# snark                              0.3.0.2
# snowballstemmer                    1.2.1
# sortedcollections                  1.0.1
# sortedcontainers                   2.0.5
# spacy                              2.0.16
# Sphinx                             1.8.1
# sphinxcontrib-websupport           1.1.0
# spyder-kernels                     0.2.6
# SQLAlchemy                         1.2.12
# statsmodels                        0.9.0
# stopit                             1.1.2
# sympy                              1.3
# tables                             3.4.4
# tabulate                           0.8.2
# tblib                              1.3.2
# tensorboard                        1.10.0
# tensorflow                         1.10.0
# termcolor                          1.1.0
# terminado                          0.8.1
# testpath                           0.3.1
# thinc                              6.12.0
# toolz                              0.9.0
# torch                              1.0.0.dev20181014
# torchvision                        0.2.1
# tornado                            5.1.1
# TPOT                               0.9.5
# tqdm                               4.26.0
# traitlets                          4.3.2
# Twisted                            17.5.0
# typed-ast                          1.1.0
# typing                             3.6.4
# ujson                              1.35
# unicodecsv                         0.14.1
# Unidecode                          1.0.22
# update-checker                     0.16
# urllib3                            1.22
# w3lib                              1.19.0
# wcwidth                            0.1.7
# webencodings                       0.5.1
# Werkzeug                           0.14.1
# wheel                              0.31.1
# widgetsnbextension                 3.4.2
# wrapt                              1.10.11
# xlrd                               1.1.0
# XlsxWriter                         1.1.1
# xlwings                            0.11.8
# xlwt                               1.2.0
# zict                               0.1.3
# zope.interface                     4.5.0

# %% [markdown]
# Choose an appropriate name for your labeled images. You can run these steps multiple times to grab different labels.

# %%
folder = 'tigers'
file = 'tigers.txt'

# %%
folder = 'lions'
file = 'lions.txt'

# %%
folder = 'kitties'
file = 'kitties.txt'

# %% [markdown]
# You will need to run this line once per each category.

# %%
path = Path('data/cats')
dest = path/folder
dest.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# Finally, upload your urls file. You just need to press 'Upload' in your working directory and select your file, then click 'Upload' for each of the displayed files.
#
# ![uploaded file](images/download_images/upload.png)

# %% [markdown]
# ## Download images

# %% [markdown]
# Now you will need to download you images from their respective urls.
#
# fast.ai has a function that allows you to do just that. You just have to specify the urls filename and the destination folder and this function will download and save all images that can be opened. If they have some problem in being opened, they will not be saved.
#
# Let's download our images! Notice you can choose a maximum number of images to be downloaded. In this case we will not download all the urls.
#
# You will need to run this line once for every category.

# %%
classes = ['tigers', 'lions', 'kitties']

# %%
# fix for bug

url = "https://wildaid.org/wp-content/uploads/2017/09/Tiger-CU.jpg"
try: r = download_url(url, dest, overwrite=True, show_progress=True)
except Exception as e: print(f"Error  {e}")
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='200' class='' max='200', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [200/200 00:09<00:00]
#     </div>
# Error https://www.washingtonpost.com/resizer/x_a0bNf08q98Z3uIRf04_YMJz0w=/480x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/JL2VM32N6U5C3DSLLFIGDQCRK4.jpg HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)
# Error https://www.indianz.com/News/2017/06/30/yellowstonegrizzlycub.jpg HTTPSConnectionPool(host='www.indianz.com', port=443): Max retries exceeded with url: /News/2017/06/30/yellowstonegrizzlycub.jpg (Caused by SSLError(SSLError("bad handshake: SysCallError(-1, 'Unexpected EOF')",),))
# Error https://www.washingtonpost.com/resizer/rNWQ6oDst_gqJ_khkSXYRtftUz4=/1484x0/arc-anglerfish-washpost-prod-washpost.s3.amazonaws.com/public/Q453GZ66JEZEZFGRDAJEPKT254.png HTTPSConnectionPool(host='www.washingtonpost.com', port=443): Read timed out. (read timeout=4)

# %%
download_images(path/file, dest  )
# Out:
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='400' class='' max='400', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [400/400 01:47<00:00]
#     </div>
# Error https://images.pexels.com/photos/40756/lion-safari-afika-landscape-40756.jpeg?auto=compress&cs=tinysrgb&h=350 'content-length'
# Error https://kidzfeed.com/wp-content/uploads/2018/08/Lion-Facts-for-kids-e1534255925789.jpg 'content-length'
# Error https://www.alisonbuttigieg.com/wp-content/uploads/2015/07/lions-fighting-mating-masai-mara-kenya-8755.jpg 'content-length'
# Error https://kopelion.org/wp-content/uploads/2016/10/Eugene.jpg 'content-length'
# Error https://buschgardens.com/handlers/ImageResizer.ashx?path=https://seaworld.scdn3.secure.raxcdn.com/tampa/-/media/busch-gardens-tampa/media-modules/750x422/animals/lions/2017_buschgardenstampabay_animals_lions7_750x422.ashx?version=1_201704102119&h=340 'content-length'
# Error http://www.earthtimes.org/newsimage/3lions130114.jpg 'content-length'
# Error https://cbsnews3.cbsistatic.com/hub/i/r/2016/01/18/9bcd54f8-6575-4012-b6c4-fdd3c6f20afb/thumbnail/1200x630/8f7446f3d59ce078f4816912c406457c/mlmain483945640x360.jpg 'content-length'
# Error https://giltedgeafrica.com/wp-content/uploads/2018/07/Banner_LionsAfrica.jpg 'content-length'
# Error https://caldwellzoo.org/wp-content/uploads/2016/02/Afrian-Lions.jpg HTTPSConnectionPool(host='caldwellzoo.org', port=443): Max retries exceeded with url: /wp-content/uploads/2016/02/Afrian-Lions.jpg (Caused by SSLError(SSLError("bad handshake: Error([('SSL routines', 'ssl3_get_server_certificate', 'certificate verify failed')],)",),))
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=310641379102289 'content-length'
# Error http://cdn0.wideopenspaces.com/wp-content/uploads/2018/07/sibunya1.jpg 'content-length'
# Error https://www.telegraph.co.uk/content/dam/news/2018/07/05/TELEMMGLPICT000168504183.jpeg?imwidth=450 'content-length'
# Error http://test3.alisonbuttigieg.com/wp-content/uploads/2015/11/lion-masai-mara-kenya-8567.jpg 'content-length'
# Error https://3sn4dm1qd6i72l8a4r2ig7fl-wpengine.netdna-ssl.com/wp-content/uploads/lion_hatari_ZA_0665.jpg 'content-length'
# Error https://www.telegraph.co.uk/content/dam/news/2018/02/12/TELEMMGLPICT000096768845_trans_NvBQzQNjv4Bqz8PrEBUoq2NOeDT9dFlgS5zo8_eVaYsgfgaGHBq6Cl8.jpeg?imwidth=450 'content-length'
# Error https://www.goeco.org/_media/media/470/4708.jpg 'content-length'
# Error http://www.alisonbuttigieg.com/wp-content/uploads/2015/11/lion-mohican-masai-mara-kenya-_j4a1748.jpg 'content-length'
# Error https://cdn.abcotvs.com/dip/images/4297863_092018-kfsn-4p-zoo-trespassing-arrest-vid.jpg 'content-length'
# Error https://lookaside.fbsbx.com/lookaside/crawler/media/?media_id=95041166497 'content-length'
# Error https://giltedgeafrica.com/images/390536544_55084b4d6f_z.jpg 'content-length'
# Error https://kidzfeed.com/wp-content/uploads/2018/08/what-do-lions-eat.jpg 'content-length'
# Error https://d.ibtimes.co.uk/en/full/1673703/lion-krugger.jpg?w=736&e=a469141d114f1563d1fe7dbfe13ece33 'content-length'
# Error http://mauritiusattractions.com/slir/w640-c2x1/content/images/gallery/90/1-walking-with-lions-mauritius.jpg 'content-length'
# Error https://easyscienceforkids.com/wp-content/uploads/2013/03/african-lion.jpg 'content-length'
# Error https://kopelion.org/wp-content/uploads/2016/10/Kimani.jpg 'content-length'
# Error https://www.rapturenewsnetwork.com/wp-content/uploads/2017/04/39077-lion-facebook.800w.tn_.jpg HTTPSConnectionPool(host='www.rapturenewsnetwork.com', port=443): Max retries exceeded with url: /wp-content/uploads/2017/04/39077-lion-facebook.800w.tn_.jpg (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x1a24cf95c0>: Failed to establish a new connection: [Errno 60] Operation timed out',))

# %%
# If you have problems download, try with `max_workers=0` to see exceptions:
# download_images(path/file, dest, max_pics=20, max_workers=0)

# %% [markdown]
# Then we can remove any images that can't be opened:

# %%
for c in classes:
    print(c)
    verify_images(path/c, delete=True, max_workers=8)
# Out:
# tigers
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='188' class='' max='188', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [188/188 00:03<00:00]
#     </div>
# /Users/jeffhale/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /Users/jeffhale/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# lions
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='199' class='' max='199', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [199/199 00:00<00:00]
#     </div>
# /Users/jeffhale/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# /Users/jeffhale/anaconda3/lib/python3.6/site-packages/PIL/Image.py:953: UserWarning: Palette images with Transparency   expressed in bytes should be converted to RGBA images
#   'to RGBA images')
# kitties
#     <div>
#         <style>
#         	/* Turns off some styling */
#         	progress {
#
#             	/* gets rid of default border in Firefox and Opera. */
#             	border: none;
#
#             	/* Needs to be in here for Safari polyfill so background images work as expected. */
#             	background-size: auto;
#             }
#
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='342' class='' max='342', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [342/342 00:02<00:00]
#     </div>

# %% [markdown]
# ## View data

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.2,
        ds_tfms=get_transforms(), size=224).normalize(imagenet_stats)

# %% [markdown]
# Good! Let's take a look at some of our pictures then.

# %%
data.classes
# Out:
# ['kitties', 'lions', 'tigers']

# %%
data.show_batch(rows=3, figsize=(7,8))

# %%
data.classes, data.c, len(data.train_ds), len(data.valid_ds)
# Out:
# (['kitties', 'lions', 'tigers'], 3, 573, 169)

# %% [markdown]
# ## Train model

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1)
# Out:
# Total time: 03:53
# epoch  train_loss  valid_loss  error_rate
# 1      0.646891    0.093045    0.017751    (03:53)

# %%
learn.save('stage-1')

# %%
learn.unfreeze()

# %%
learn.lr_find()
# Out:
# LR Finder complete, type {learner_name}.recorder.plot() to see the graph.

# %%
learn.recorder.plot()

# %%
learn.fit_one_cycle(1, max_lr=slice(3e-5,3e-4))
# Out:
# Total time: 04:30
# epoch  train_loss  valid_loss  error_rate
# 1      0.155468    0.074385    0.029586    (04:30)

# %%
learn.save('stage-2')

# %% [markdown]
# ## Interpretation

# %%
learn.load('stage-2')

# %%
interp = ClassificationInterpretation.from_learner(learn)

# %%
interp.plot_confusion_matrix()

# %% [markdown]
# ## Cleaning Up
#
# Some of our top losses aren't due to bad performance by our model. There are images in our data set that shouldn't be.
#
# Using the `FileDeleter` widget from `fastai.widgets` we can prune our top losses, removing photos that don't belong.
#
# First we need to get the file paths from our top_losses. Here's a handy function that pulls out all our top_losses:

# %%
from fastai.widgets import *

losses,idxs = interp.top_losses()
top_loss_paths = data.valid_ds.x[idxs]

# %% [markdown]
# Now we can pass in these paths to our widget.

# %%
fd = FileDeleter(file_paths=top_loss_paths)
# Out:
# HBox(children=(VBox(children=(Image(value=b'\xff\xd8\xff\xe0\x00\x10JFIF\x00\x01\x01\x00\x00\x01\x00\x01\x00\x…
# Button(button_style='primary', description='Confirm', style=ButtonStyle())

# %% [markdown]
# Flag photos for deletion by clicking 'Delete'. Then click 'Confirm' to delete flagged photos and keep the rest in that row. The `File_Deleter` will show you a new row of images until there are no more to show. In this case, the widget will show you images until there are none left from `top_losses`.

# %% [markdown]
# ## Putting your model in production

# %%
data.classes
# Out:
# ['kitties', 'lions', 'tigers']

# %% [markdown]
# You probably want to use CPU for inference, except at massive scale (and you almost certainly don't need to train in real-time). If you don't have a GPU that happens automatically. You can test your model on CPU like so:

# %%
# fastai.defaults.device = torch.device('cpu')

# %%
img = open_image(path/'kitties'/'00000021.jpg')
img
# Out:
# Image (3, 211, 281)

# %%
#classes = ['black', 'grizzly', 'teddys']
data2 = ImageDataBunch.single_from_classes(path, classes, tfms=get_transforms(), size=224).normalize(imagenet_stats)
learn = create_cnn(data2, models.resnet34)
learn.load('stage-2')

# %%
pred_class,pred_idx,outputs = learn.predict(img)
pred_class
# Out:
# 'tigers'

# %% [markdown]
# So you might create a route something like this ([thanks](https://github.com/simonw/cougar-or-not) to Simon Willison for the structure of this code):
#
# ```python
# @app.route("/classify-url", methods=["GET"])
# async def classify_url(request):
#     bytes = await get_bytes(request.query_params["url"])
#     img = open_image(BytesIO(bytes))
#     _,_,losses = learner.predict(img)
#     return JSONResponse({
#         "predictions": sorted(
#             zip(cat_learner.data.classes, map(float, losses)),
#             key=lambda p: p[1],
#             reverse=True
#         )
#     })
# ```
#
# (This example is for the [Starlette](https://www.starlette.io/) web app toolkit.)

# %% [markdown]
# ## Things that can go wrong

# %% [markdown]
# - Most of the time things will train fine with the defaults
# - There's not much you really need to tune (despite what you've heard!)
# - Most likely are
#   - Learning rate
#   - Number of epochs

# %% [markdown]
# ### Learning rate (LR) too high

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %%
learn.fit_one_cycle(1, max_lr=0.5)

# %% [markdown]
# ### Learning rate (LR) too low

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate)

# %% [markdown]
# Previously we had this result:
#
# ```
# Total time: 00:57
# epoch  train_loss  valid_loss  error_rate
# 1      1.030236    0.179226    0.028369    (00:14)
# 2      0.561508    0.055464    0.014184    (00:13)
# 3      0.396103    0.053801    0.014184    (00:13)
# 4      0.316883    0.050197    0.021277    (00:15)
# ```

# %%
learn.fit_one_cycle(5, max_lr=1e-5)

# %%
learn.recorder.plot_losses()

# %% [markdown]
# As well as taking a really long time, it's getting too many looks at each image, so may overfit.

# %% [markdown]
# ### Too few epochs

# %%
learn = create_cnn(data, models.resnet34, metrics=error_rate, pretrained=False)

# %%
learn.fit_one_cycle(1)

# %% [markdown]
# ### Too many epochs

# %%
np.random.seed(42)
data = ImageDataBunch.from_folder(path, train=".", valid_pct=0.9, bs=32, 
        ds_tfms=get_transforms(do_flip=False, max_rotate=0, max_zoom=1, max_lighting=0, max_warp=0
                              ),size=224, num_workers=4).normalize(imagenet_stats)

# %%
learn = create_cnn(data, models.resnet50, metrics=error_rate, ps=0, wd=0)
learn.unfreeze()

# %%
learn.fit_one_cycle(40, slice(1e-6,1e-4))
